# %%
import pandas as pd
import investpy as inv
import yfinance as yf
import pprint
p = pprint.PrettyPrinter(indent=4)

countries= "brazil" 
from_date='01/01/2021'
to_date='01/01/2022'

# %%
a = yf.Ticker('petr3.sa')

# %%
p.pprint(a.info)
# Out:
# {   '52WeekChange': 0.5008584,
#     'SandP52WeekChange': 0.1372788,
#     'address1': 'Avenida RepUblica do Chile, 65',
#     'address2': 'Centro',
#     'algorithm': None,
#     'annualHoldingsTurnover': None,
#     'annualReportExpenseRatio': None,
#     'ask': 34.96,
#     'askSize': 0,
#     'averageDailyVolume10Day': 20668140,
#     'averageVolume': 20114289,
#     'averageVolume10days': 20668140,
#     'beta': 1.305258,
#     'beta3Year': None,
#     'bid': 34.99,
#     'bidSize': 0,
#     'bookValue': 29.694,
#     'category': None,
#     'circulatingSupply': None,
#     'city': 'Rio De Janeiro',
#     'companyOfficers': [],
#     'country': 'Brazil',
#     'currency': 'BRL',
#     'currentPrice': 35,
#     'currentRatio': 1.247,
#     'dateShortInterest': None,
#     'dayHigh': 35.32,
#     'dayLow': 34.49,
#     'debtToEquity': 84.146,
#     'dividendRate': 8.51,
#     'dividendYield': 0.24350001,
#     'earningsGrowth': -0.474,
#     'earningsQuarterlyGrowth': -0.474,
# ...

# %%
p.pprint(a.actions)
# Out:
#             Dividends  Stock Splits
# Date
# 2005-09-01   0.000000           4.0
# 2008-04-28   0.000000           2.0
# 2008-12-29   0.042600           0.0
# 2009-04-09   0.351600           0.0
# 2009-07-06   0.300000           0.0
# 2009-10-01   0.200000           0.0
# 2009-12-21   0.200000           0.0
# 2010-04-23   0.102085           0.0
# 2010-05-24   0.170000           0.0
# 2010-08-02   0.170000           0.0
# 2010-11-03   0.140000           0.0
# 2010-12-22   0.200000           0.0
# 2011-03-22   0.173420           0.0
# 2011-04-29   0.126500           0.0
# 2011-05-12   0.201800           0.0
# 2011-08-03   0.207300           0.0
# 2011-11-14   0.200000           0.0
# 2012-01-03   0.177300           0.0
# 2012-03-20   0.124400           0.0
# 2012-05-14   0.200000           0.0
# 2013-04-30   0.134310           0.0
# 2014-04-03   0.538080           0.0
# 2018-05-22   0.050000           0.0
# 2018-08-14   0.050000           0.0
# 2018-11-22   0.100000           0.0
# ...
